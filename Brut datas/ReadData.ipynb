# %%
#################################################
#created the 23/04/2018 12:57 by Alexis Blanchet#
#################################################


import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import os
import scipy.stats
import matplotlib
import plotly.offline as offline
import plotly.graph_objs as go
import datetime
import json
from pandas.io.json import json_normalize

import pandas as pd
pd.set_option('display.height', 1000)
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 50)
pd.set_option('display.width', 1000)

# %%
DATA_FILE = 'dataBrut_ex.log'

# %%
# Need to convert the log file to an Array of JSON objects.
json_rows = []
f = open(DATA_FILE,'r')
for l in f:
    row = json.loads(l)
    json_rows.append(row)

# Load into a Pandas Dataframe
df = json_normalize(json_rows)

# %%
df
# Out:
#            agt        caid       cid ctype       from groupId               ifw             iip          imac             ip  lcn     lzd                               mac       nid         noid   op            rts   seq               sfw         shw    si                sn  sq    st         sui    t             ts  v
# 0       UI/1.0   568501519  67749067  fttb     repeat      30        NCC_1.4.11         0.0.0.0  4065A3028378   10.249.1.182  156   90612  cda97fc5317562bc607e1d2508f22523  00,30155  30155.25801  SFR  1523875378770  1680  1.8.5.0-0_SFR_RS        3945   975  CANAL+ DECALE HD  hd  dvbc       5.5.6  127  1523875348716  4
# 1  UDPLOGGER/1         NaN       NaN   NaN     repeat     NaN               NaN             NaN           NaN     85.68.0.10    1    3780  c53225fec4bf63d26dadba871b641c52     30148          NaN  LPM  1523875378773   557     1.7.22_SFR_RS  labox_3945     1            TF1 HD  hd  dvbc  4.2.0-10_3  127  1523882552283  4
# 2       UI/1.0  2220260665  A3711802  fttb     repeat    1402  NCC-PC20_3.431.0    92.93.206.90  4065A31FE1D8  10.245.79.158   23    7500  8ad111f1e9c7b220bc9abca7e25c61ca  00,30115  30115.22401  SFR  1523875378775    27     5.6.1.5-0_RNS        3044   655         NUMERO 23  hd  dvbc       5.5.6  127  1523875355533  4
# 3       UI/1.0   567960934  60682674  fttb     repeat     192        NCC_1.4.11  89.159.158.195  D084B0F969C8  10.235.84.150    1     600  cc5dbcadf50a53f956fd9872f9db0c96  00,50120  50120.21701  SFR  1523875378783     3  1.8.5.0-0_SFR_RS        3944     1            TF1 HD  hd  dvbc       5.5.6  127  1523875349218  4
# 4       UI/1.0   568495241  67154898  fttb     repeat     118        NCC_1.4.11         0.0.0.0  5464D94F5770  10.142.82.157    6   56401  d2aa10410b4073b62468663ed394508c  00,30044  30044.41301  SFR  1523875378779  5655      1.8.3_SFR_RS        3945     6             M6 HD  hd  dvbc       5.5.6  127  1523875347859  4
# 5       UI/1.0   576416109  A7497702  fttb  numbering     119   NCC-PC20_1.4.11   109.10.86.141  181E78D66000  10.241.12.197    9      32  acd2e59aee23ea357bd0521de6ce21a7  00,30016  30016.20501  SFR  1523875378777   474  1.8.5.0-0_SFR_RS        3945   475             W9 HD  hd  dvbc       5.5.6  127  1523875354216  4
# 6       UI/1.0  2219900397  A1651939  fttb  numbering       4  NCC-PC20_3.431.0    93.7.239.197  4883C7A9F560  10.250.169.84    2       2  ec1380b7f171b558226eb2413c3db6a5  00,30189  30189.24901  SFR  1523875378778    97     5.6.1.5-0_RNS        3044     2       FRANCE 2 HD  hd  dvbc       5.5.6  127  1523875355172  4
# 7       UI/1.0   576395686  A7098851  fttb     repeat     446               NaN             NaN           NaN   192.168.0.13   11    5700  ecf7c05f3d4bbba1e00becc96f848d38  00,30027  30027.28401  RED  1523875378782    20         3.3.7.1-0        3034  1098               TFX  hd  dvbc       5.5.8  127  1523875366690  4
# 8       UI/1.0   576312251  A5925687  fttb     repeat    1290               NaN             NaN           NaN   192.168.0.13  115  920102  24fefa63f461c8aba196344aaf15b6db  00,30133  30133.24901  SFR  1523875378778  3068         3.3.6.6-0        3034   960  BEIN SPORTS 1 HD  hd  dvbc       5.5.8  127  1523875339101  4
# 9       UI/1.0   568615054  B0245466  fttb     repeat     118   NCC-PC20_1.4.11    85.68.82.181  A01B29F03FD8   10.142.78.15    6       0  1fb51d339373f7cfb4aa702713b500a8  00,30044  30044.41201  SFR  1523875378790    20  1.8.5.0-0_SFR_RS        3945     6             M6 HD  hd  dvbc       5.5.6  127  1523875364088  4

# %%
df.describe()
# Out:
#            agt       caid       cid ctype    from groupId         ifw      iip          imac            ip lcn lzd                               mac       nid         noid   op            rts seq               sfw   shw  si     sn  sq    st    sui    t             ts   v
# count       10          9         9     9      10       9           7        7             7            10  10  10                                10        10            9   10             10  10                10    10  10     10  10    10     10   10             10  10
# unique       2          9         9     1       2       8           3        6             7             9   8  10                                10         9            9    3              9   9                 6     5   8      8   1     1      3    1             10   1
# top     UI/1.0  567960934  67749067  fttb  repeat     118  NCC_1.4.11  0.0.0.0  181E78D66000  192.168.0.13   1   2  acd2e59aee23ea357bd0521de6ce21a7  00,30044  30133.24901  SFR  1523875378778  20  1.8.5.0-0_SFR_RS  3945   1  M6 HD  hd  dvbc  5.5.6  127  1523875339101   4
# freq         9          1         1     9       8       2           3        2             1             2   2   1                                 1         2            1    8              2   2                 4     4   2      2  10    10      7   10              1  10

# %%
df2 = pd.read_csv('iptv.buffer',sep=';')

# %%
df2.head()
# Out:
#          date          type                               mac  idconst  ftype
# 0  1523876443  cleaned_iptv  12b0e74c19a0ced82a41fa058e44f5ef     80.0    1.0
# 1  1523876450  cleaned_iptv  f79623289128444afdfc829f23432e4b    226.0    0.0
# 2  1523876457  cleaned_iptv  8e5598aa0b239fe1517d205e1a290f4b    346.0    0.0
# 3  1523876457  cleaned_iptv  b1b0996403264432246c1a71df3cacea    445.0    0.0
# 4  1523876458  cleaned_iptv  b202cbcb2efc0cbdafa492382f1cb2f0    192.0    0.0
