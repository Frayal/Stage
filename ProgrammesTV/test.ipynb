# %%
#################################################
#created the 25/04/2018 11:10 by Alexis Blanchet#
#################################################
import numpy as np
import pandas as pd
import xml.etree.ElementTree as ET
import xmltodict, json
from collections import OrderedDict
PATH = '/home/alexis/Bureau/Stage/ProgrammesTV/pluri_201712/2017-12-02_programmeTV/IPTV_0192_2017-12-02_TF1.xml'

import pandas as pd
pd.set_option('display.height', 1000)
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

tree = ET.parse(PATH)
root = tree.getroot()


#print(root.tag)
l1 = [child for child in root]
#print(l1)
l2 = [[child for child in root] for root in l1 ]
#print(l2[1])

data = pd.DataFrame()
for i,elem in enumerate(l2[1]):
    xmlstr = ET.tostring(elem)
    o = xmltodict.parse(xmlstr)
    o = load_dic(o)
    df2 = pd.DataFrame.from_dict(o["DIFFUSION"],orient = 'index').rename(columns={0: i})
    data = [data,df2.T]
    data = pd.concat(data)
    
    
temp_data = pd.DataFrame()   
for i in range(data.shape[0]):    
    df = data['ATTRIBUTS']
    l = (df[[i]].values)[0]
    df2 = pd.DataFrame.from_dict(l,orient = 'index')
    df2 = df2.rename(columns = {0: i})
    #print(df2.head())
    temp_data = [temp_data,df2]
    temp_data = pd.concat(temp_data,axis = 1)
temp_data.head()
data = data.join(temp_data.T)
temp_data = pd.DataFrame() 
for i in range(data.shape[0]):    
    df = data['EMISSION']
    l = (df[[i]].values)[0]
    df2 = pd.DataFrame.from_dict(l,orient = 'index')
    df2 = df2.rename(columns = {0: i})
    #print(df2.head())
    temp_data = [temp_data,df2]
    temp_data = pd.concat(temp_data,axis = 1)
    temp_data = temp_data.drop(['@DATEMODIF'])

temp_data.head()
data = data.join(temp_data.T)
temp_data = pd.DataFrame() 
data = data.drop(['ATTRIBUTS','EMISSION'],axis = 1)

for i in range(data.shape[0]):    
    df = data['FORMAT']
    l = (df[[i]].values)[0]
    df2 = pd.DataFrame.from_dict(l,orient = 'index')
    df2 = df2.rename(columns = {0: i})
    #print(df2.head())
    temp_data = [temp_data,df2]
    temp_data = pd.concat(temp_data,axis = 1)
temp_data = temp_data.drop(['#text'])
temp_data = temp_data.T.rename(columns={"@CLE": "CLE-FORMAT"})

temp_data.head()
data = data.join(temp_data)
temp_data = pd.DataFrame() 
data = data.drop(['FORMAT'],axis=1)

for i in range(data.shape[0]):    
    df = data['GENRE']
    l = (df[[i]].values)[0]
    df2 = pd.DataFrame.from_dict(l,orient = 'index')
    df2 = df2.rename(columns = {0: i})
    #print(df2.head())
    temp_data = [temp_data,df2]
    temp_data = pd.concat(temp_data,axis = 1)
    temp_data = temp_data.drop(['@GENRESIMPLE'])

temp_data = temp_data.T.rename(columns={"@CLE": "CLE-GENRE","#text":"description programme"})
temp_data.head()
data = data.join(temp_data)
temp_data = pd.DataFrame() 

data = data.drop(['GENRE'],axis=1)
names = data.columns.values
irrelevant = ['LESPERSONNES','LESTEXTES','PHOTO','MAGAZINEXY','SERIE','NATIONALITE','FILMTELEFILM']
n = list(set(names) - set(irrelevant))
data = data[n]


data['DATE'] = data['DATEHEURE'].apply(lambda x: x.split('T')[0])
data['HEURE'] = data['DATEHEURE'].apply(lambda x: x.split('T')[1])
data['minutes'] = data['HEURE'].apply(lambda x: int(x.split(':')[0])*60 + int(x.split(':')[1]))
data
    
    

data
# Out:
#    INEDIT_CRYPTE PT3 STEREO            DATEHEURE DIRECT HD DERDIF DIFFERE                   TITREEMISSION STM NOUVEAUTE           @DATEMODIF VOST VM PREMDIF DOLBY51 CLE-GENRE CLAIR REDIF    @CLEEMI RESUME RATIO DOLBY CLE-FORMAT PT2 CSA    @CLEDIF OCCULTATIONMOBILE       description programme                                       SOUSTITREDIF                           TITRE TEMPSFORT DUREE INEDIT_EN_CLAIR PT1        DATE     HEURE  minutes
# 0              0   0      1  2017-12-02T06:30:00      0  1      0       0                            TFou   1         0  2017-11-17T16:57:57    0  0       0       0       403     0     0  123145858      0  16:9     0         12   0   1  167884259                 0           Magazine jeunesse                                                NaN                            TFou         0   105               1   0  2017-12-02  06:30:00      390
# 1              0   0      1  2017-12-02T08:15:00      1  1      0       0             Téléshopping samedi   0         0  2017-11-17T16:57:57    0  0       0       0       425     0     0  123145084      0  16:9     0         12   0   1  167884260                 0      Magazine de télé-achat                                                NaN             Téléshopping samedi         0   135               0   0  2017-12-02  08:15:00      495
# 2              0   0      1  2017-12-02T10:30:00      0  1      0       0               Nos chers voisins   1         0  2017-11-17T16:57:57    0  0       0       0        31     0     0  123145635      0  16:9     0          3   0   1  167884261                 0          Série humoristique                                                NaN               Nos chers voisins         0    70               0   0  2017-12-02  10:30:00      630
# 3              0   0      1  2017-12-02T11:40:00      0  1      0       0       Petits plats en équilibre   1         0  2017-11-17T16:57:57    0  0       0       0       397     0     0  123145085      0  16:9     0         12   0   1  167884262                 0  Magazine de la gastronomie                                                NaN       Petits plats en équilibre         0     5               0   0  2017-12-02  11:40:00      700
# 4              0   0      1  2017-12-02T11:45:00      0  1      0       0         L'affiche de la semaine   1         0  2017-11-17T16:57:57    0  0       0       0       424     0     0  123145086      0  16:9     0         12   0   1  167884263                 0            Magazine sportif                                                NaN         L'affiche de la semaine         0    15               0   0  2017-12-02  11:45:00      705
# 5              0   0      1  2017-12-02T12:00:00      0  1      0       0         Les douze coups de midi   1         0  2017-11-17T16:57:57    0  0       0       0       950     0     0  123145087      0  16:9     0         16   0   1  167884264                 0                         Jeu                                                NaN         Les douze coups de midi         0    50               0   0  2017-12-02  12:00:00      720
# 6              0   0      1  2017-12-02T12:50:00      0  1      0       0                           Météo   1         0  2017-11-17T16:57:57    0  0       0       0       951     0     0  123145088      0  16:9     0         16   0   1  167884265                 0                       Météo                                                NaN                           Météo         0     5               0   0  2017-12-02  12:50:00      770
# 7              0   0      1  2017-12-02T12:55:00      0  1      0       0               L'affiche du jour   1         0  2017-11-17T16:57:58    0  0       0       0       424     0     0  123145089      0  16:9     0         12   0   1  167884266                 0            Magazine sportif                                                NaN               L'affiche du jour         0     5               0   0  2017-12-02  12:55:00      775
